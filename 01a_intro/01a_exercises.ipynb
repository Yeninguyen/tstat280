# %% [markdown]
# ## Amazon Laptop Dataset
#
# Jordan Blake has been reviewing the company’s growing dataset of laptop listings collected from several online retailers. The dataset contains information such as product titles, prices, discounts, customer ratings, review counts, and technical details extracted from product pages. Jordan wants the data scientist to use this large dataset to support better decision-making about how laptops should be priced and marketed on the platform.
#
# One of Jordan’s goals is to create a system that can estimate what price a laptop should sell for based on its specifications and listing information—things like processor type, RAM, storage, brand, and display size that appear in the product titles and technical details. Jordan also wants a tool that can automatically determine whether a laptop listing will likely receive strong customer ratings based on its specifications, price, and early engagement signals such as review counts. In addition, Jordan is curious whether the laptops in the dataset naturally fall into meaningful groups. By identifying clusters of similar devices—such as budget laptops, gaming laptops, and premium ultrabooks—the company could better understand the structure of the market and improve how products are categorized and recommended to customers.
#
# The dataset was assembled by Daniel Kim, who built automated data pipelines that gather laptop listings from e-commerce websites through web scraping and API requests. His scripts collect product titles, pricing information, discounts, ratings, review counts, and technical specification fields, then store everything in a structured dataset so it can be analyzed using tools like Python and Pandas.
#
# Maya Rodriguez has already begun exploring the dataset and can help by performing exploratory analysis. She can calculate summary statistics, create visualizations of price distributions and ratings, and investigate relationships between features such as brand, price, and customer feedback. Her exploratory work will help identify patterns, detect outliers, and guide which variables are most useful when building models.
#
# Liam Chen will help once the models are ready to be used in practice. He can take the models developed using tools such as Scikit-Learn and integrate them into the company’s data systems so predictions can be generated automatically when new laptop listings appear. Liam can also help build processes that regularly retrain the models as more data is collected.
#
# Priya Nair has extensive experience in the laptop and consumer electronics market. She understands how different specifications influence consumer purchasing decisions and how brands position their devices. Priya can help interpret patterns discovered in the analysis, confirm whether the groups of laptops identified by the models make sense from a market perspective, and suggest additional features—such as processor generation or GPU class—that may improve the models.

# %% [markdown]
# ### Data Science Workflow Exercises

# %% [markdown]
# #### Exercise 1
#
# Recall the different steps of the data science workflow:
#
# 1. **Define** the problem or question
# 2. **Collect** and acquire data
# 3. **Clean** and prepare the data
# 4. **Explore** and analyze the data
# 5. **Build** models or apply statistical methods
# 6. **Evaluate** results
# 7. **Communicate** results and deploy models
#
# Describe what each component of the data science workflow would look like for this project. Feel free to look at a sample dataset in `amazon_laptop.csv` found in the `data` folder as you consider your answer.
#
# This is my answer
# 1. Based on the dataset, the company wants to predict the price, and the high rating of customers would be for the laptop, using laptop specifications to analyze natural categories of laptops for customers in the market.
# 2. The data was gathered from e-commerce websites using web scraping and APIs. The dataset includes product titles, prices, discounts, ratings, review counts, and technical specifications.
# 3. The dataset was prepared by cleaning and handling missing values, as well as transforming raw scraped data into a structured dataset, organizing features like price, ratings, and specifications into usable columns.
# 4. The dataset was identified with patterns, detected outliers, and guided which variables are most useful when building models. Using visualizations and summary statistics to understand how price relates to brand, ratings, and other features.
# 5. Identified the regression and categorized values for the dataset, as well as built models using the clustering method, and maintained a machine learning system that predicts laptop prices based on features like RAM, storage, and processor type.
# 6. Evaluated the result after running the model, as well as reviewed model results, and determined whether identified clusters.
# 7. An engineer integrates trained models into production systems so predictions can be generated automatically for new laptop listings.

# %% [markdown]
# #### Exercise 2
#
# For each part of the data science workflow, discuss what problems might arise if that part of the workflow is skipped?
# 1. **Define** the problem or question - if this part is skipped, it will lead to wrong decision-making and unclear goals
# 2. **Collect** and acquire data - if this part is skipped, the dataset will be inconsistent and cannot be completed
# 3. **Clean** and prepare the data - if this part is skipped, the dataset will be incorrect and missing data, leading to misreading results
# 4. **Explore** and analyze the data - if this part is skipped, the process of identifying important patterns, outliers, or relationships between features may be missed
# 5. **Build** models or apply statistical methods - if this part is skipped, the model will be incomplete and no prediction will be made
# 6. **Evaluate** results - if this part is skipped, there is no reflection on performance, and the team may not know whether the model produces accurate or incorrect results
# 7. **Communicate** results and deploy models - if this part is skipped, there is no communication of insight with other roles, and the model cannot integrate and apply prediction to new laptops

# %% [markdown]
# #### Exercise 3
#
# Which of the problems described in the brief sounds like supervised learning problems? Of these, which sounds like a regression problem and which sounds like a classification problem?
# Predicting the prices and high customer ratings of laptops sounds like a supervised learning problem. Prices of laptops are numerical values, so it would be a regression problem, and high customer ratings are categorical values, so it would be a classification problem

# %% [markdown]
# #### Exercise 4
#
# Which of the problems described in the brief sounds like an unsupervised learning problem?
# Clusters of similar devices—such as budget laptops, gaming laptops, and premium ultrabooks sound like an unsupervised learning problem

# %% [markdown]
# #### Exercise 5
#
# Recall the different roles involved in the data science workflow:
#
# - **Stakeholders** – define the problem, set goals, and use results to make decisions - Jordan Blake
# - **Domain Experts (SMEs)** – provide subject-matter knowledge and help interpret results in context - Priya Nair
# - **Data Engineers** – collect, store, and manage data - Daniel Kim
# - **Data Scientists / Statisticians** – analyze data and build models - Maya Rodriguez
# - **Data Analysts** – explore data and communicate insights - Maya Rodriguez
# - **Machine Learning Engineers** – deploy and maintain models in production - Liam Chen
#
# For each person mentioned in the brief, identify which of these roles that individual most likely fills.

# %% [markdown]
# #### Exercise 6
#
# For each role, discuss what challenges might arise during the project if there wasn't someone to fill that role?
# Stakeholders - if the project does not have someone to set a goal and define a problem, it will lead to no clear goal and take longer to finish the project
# Data Engineer - without a data engineer role, the project leads to a messy dataset, and the data pipeline may fail
# Data Analysts - leads to missing patterns or outlier values
# Domain Experts - the result might be misinterpreted, and cannot identify meaningful grouping
# Machine Learning Engineer - leads to an outdated model, and new laptops cannot be deployed for prediction.
# Data Scientists - no one builds models and analyzes the data, leading to the project being unable to finish.

# %% [markdown]
# #### Exercise 7
#
# For each role, discuss which part(s) of the workflow they would support.
# Jordan Blake - Stakeholders - he defines the problem, reviews the outcome, evaluates the results, and uses the results to make a decision.
# Daniel Kim - Data Engineer - collects and prepares the data.
# Maya Rodriguez - Data Analysts - explore data and communicate insights.
# Priya Nair - Domain Experts - interpret the results and validate models.
# Liam Chen - Machine Learning Engineer - deploy and maintain models.
# Maya Rodriguez - Data Scientists - build the model and evaluate results.

# %% [markdown]
# I completed each exercise and everything worked as expected
