# %% [markdown]
# 1. Who is the stakeholder and what do they want to accomplish?
# Maya is the stakeholder and she want to create a small app where
# they can enter details about a home and see the predicted price. It should be easy to understand
# and not require technical knowledge to use.
#
# 2. Is this a supervised learning or unsupervised learning problem? If it is a supervised learning problem, does it sound like a regression or classification task?
# This is a supervised learning problem. It sounds like a regression task because the problem come with home prices output is a continuous number.
#
# 3. Which of the individuals sounds like a data engineer?
# Luis is a data engineer
#
# A. Where do the data come from?
# The data come from different sources, inlcuding home data (size, prices, number of rooms), surrounding area data (crime reports, neighborhood, parks, schools, restaurants, and trains)
#
# B. What problems are there with the data?
# Missing values in some columns
# Inconsistent formatting (especially for locations or names)
# Possible duplicates or repeated entries
# Data collected at different times or levels of detail
#
# C. How will you address any of these problems?
# Missing values - Remove rows or handle missing values by using mean/meadian methods.
# Inconsistent formatting - Correct and keep the format looks clean, consistent, and standardize.
# Possible duplicates - Identify duplicate entries in the data and remove them to ensure each observation is counted only once.
# Data collected at different times - Aggregrate the data to consistent level so that all sources are comparable.
#
# 4. Which of the individuals sounds like a data analyst?
# Aisha is a data anayst
#
# A. What are some trends they've noticed in the past?
# They noticed that home prices very different, even for similar houses. Location plays a major role in determining price, and features like square footage and number of bedrooms matter, but not always in a simple way.
#
# B. What are some suggestions they have for future data analyses?
# Look at how price relates to size, number of rooms, and lot size
# Compare prices across different areas
# See whether homes near certain types of places (like parks or schools) tend to be priced
# differently
# Check if there are any unusual or extreme values that might affect the results
#
# 5. Which of the individuals sounds like a machine learning engineer?
# Ethan is a mchine learning engineer
#
# What are some things to consider when building the model?
# When building the model, it is important to regularly checking your approach stay on the right track, and test our approach on data it hasn’t seen before to make sure it does not overfit.
#
# What are some things to consider when presenting the model for others to use?
# When it comes to sharing the results, simplicity is key. The tool we build should let someone
# enter a few details about a home and quickly get a prediction. It should be clear what inputs are
# required and easy to interpret the output.
# What are some things you want to account for when deploying the model?
# What happens if someone enters unusual or incomplete information
# How fast the tool responds
# Whether the results are easy to trust and understand
#
# 6. Which of the individuals sounds like a subject matter expert?
# Dr. Chen is the subject matter expert
#
# What variables will be useful for prediction?
# Location, neighborhood close to parks, schools, or certain amenities can increase value. higher crime levels might
# bring prices down. Distance to parks, amenities and schools are matters. Combination features such as house size with neighborhood quality are also important for predicting price.
#
# What variables aren't readily available that might require extra effort to construct?
# Distance based variables measure how far a home is from schools, parks, and other amenities, usually calculated in miles or similar units.
# Neighborhood desirability can be measured using a rating based on factors like safety and overall area quality.
