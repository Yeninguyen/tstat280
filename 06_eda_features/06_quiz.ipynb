# %% [markdown]
# ### Quiz

# %% [markdown]
# #### Part 1
#
# Load the dataset found in `hr.csv`. Then create a visualization that would easily allow you to answer the following question:
#
# - Which performance score is most common?

# %%
# YOUR CODE HERE
import pandas as pd
import seaborn as sns
df = pd.read_csv("../data/hr.csv")
df.head()
sns.countplot(data=df, x="PerformanceScore")
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='count'>

# %% [markdown]
# #### Part 2
#
# Create a visualization that would allow you to easily answer the following question:
#
# - What does the distribution of the `Salary` of an employee look like?

# %%
# YOUR CODE HERE
sns.histplot(data=df, x="Salary")
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %% [markdown]
# #### Part 3
#
# Create a visualization that would allow you to easily answer the following question:
#
# - How does the distribution of `EngagementSurvey` differ for the categories in `PerformanceScore`?

# %%
# YOUR CODE HERE
sns.boxplot(data=df, x="PerformanceScore", y="EngagementSurvey", hue="PerformanceScore")
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='EngagementSurvey'>

# %% [markdown]
# #### Part 4
#
# Create a visualization that would allow you to easily answer the following question:
#
# - What does the relationship between the log of `Salary` and `Absences` look like?

# %%
# YOUR CODE HERE
import numpy as np
df.head()
df["log_salary"] = np.log(df["Salary"])
sns.scatterplot(data=df, x="Absences", y="log_salary")
# Out:
# <Axes: xlabel='Absences', ylabel='log_salary'>

# %% [markdown]
# #### Part 5
#
# Create a visualization that would allow you to easily answer the following question:
#
# - Does there appear to any association between `EmploymentStatus` and `Department`

# %%
# YOUR CODE HERE
df.head()
sns.countplot(data=df, x="EmploymentStatus", hue="Department")
# Out:
# <Axes: xlabel='EmploymentStatus', ylabel='count'>

# %%
map_cor = pd.crosstab(df["EmploymentStatus"],df["Department"])
sns.heatmap(map_cor, annot=True)
# Out:
# <Axes: xlabel='Department', ylabel='EmploymentStatus'>
