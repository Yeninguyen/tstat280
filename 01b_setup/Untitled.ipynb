# %%
import sys
import numpy as np
import os

env_name = os.environ.get("CONDA_DEFAULT_ENV", "Unknown")

print(f"Environment: {env_name}")
print(f"Python version: {sys.version.split()[0]}")
print(f"Numpy version: {np.__version__}")
# Out:
# Environment: quiz1b_env
# Python version: 3.12.13
# Numpy version: 2.4.4
